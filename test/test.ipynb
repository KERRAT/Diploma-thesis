# %%
import OCR
from tensorflow.keras.models import load_model

model_path = 'UkrainianOCR/examples/Ukrainian_OCR_extended_Resnet_with_blure_and_aug_new.h5'

model = load_model(model_path)


print(OCR.process_image('Ukr/1_page.jpg', model))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import OCR
#       2 from tensorflow.keras.models import load_model
#       4 model_path = 'UkrainianOCR/examples/Ukrainian_OCR_extended_Resnet_with_blure_and_aug_new.h5'
#
# File d:\programming\Диплом\OCR.py:11
#       8 import tempfile
#      10 model_path = 'UkrainianOCR/examples/Ukrainian_OCR_extended_Resnet_with_blure_and_aug_new.h5'
# ---> 11 model = load_model(model_path)
#      13 def resize_image(image, max_size=960):
#      14     height, width = image.shape[:2]
#
# File d:\programming\miniconda\envs\DeepLearning\lib\site-packages\tensorflow\python\keras\saving\save.py:184, in load_model(filepath, custom_objects, compile)
#     181 with generic_utils.CustomObjectScope(custom_objects or {}):
#     182   if (h5py is not None and (
# ...

# %%
import tensorflow as tf

# Завантажте модель Keras у форматі .h5
model = tf.keras.models.load_model("../UkrainianOCR/examples/Ukrainian_OCR_extended_Resnet_with_blure_and_aug_new.h5")

# Збережіть модель у форматі TensorFlow SavedModel
model.save("Ukrainian_OCR_SavedModel")
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 31). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Ukrainian_OCR_SavedModel\assets
# INFO:tensorflow:Assets written to: Ukrainian_OCR_SavedModel\assets

# %%
import cv2
import matplotlib.pyplot as plt

# Завантаження зображення
image = cv2.imread('res.jpeg', cv2.IMREAD_GRAYSCALE)

# Інвертування зображення
inverted_image = cv2.bitwise_not(image)

# Налаштування відображення
fig, axes = plt.subplots(2, 1, figsize=(30, 10))

# Відображення оригінального зображення
axes[0].imshow(image, cmap='gray')
axes[0].set_title('Original Image')
axes[0].axis('off')

# Відображення інвертованого зображення
axes[1].imshow(inverted_image, cmap='gray')
axes[1].set_title('Inverted Image')
axes[1].axis('off')

# Відображення графіків
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Завантаження зображення
image = cv2.imread('res.png', cv2.IMREAD_GRAYSCALE)

# Масштабування зображення з різними методами інтерполяції
scale_factor = 0.1
scaled_image_bilinear = cv2.resize(image, None, fx=scale_factor, fy=scale_factor, interpolation=cv2.INTER_LINEAR)
scaled_image_bicubic = cv2.resize(image, None, fx=scale_factor, fy=scale_factor, interpolation=cv2.INTER_CUBIC)
scaled_image_lanczos = cv2.resize(image, None, fx=scale_factor, fy=scale_factor, interpolation=cv2.INTER_LANCZOS4)

# Налаштування відображення
fig, axes = plt.subplots(2, 2, figsize=(12, 12))

# Відображення оригінального зображення
axes[0, 0].imshow(image, cmap='gray')
axes[0, 0].set_title('Original Image')
axes[0, 0].axis('off')

# Відображення масштабованого зображення з білінійним згладжуванням
axes[0, 1].imshow(scaled_image_bilinear, cmap='gray')
axes[0, 1].set_title('Scaled Image - Bilinear Interpolation')
axes[0, 1].axis('off')

# Відображення масштабованого зображення з бікубічним згладжуванням
axes[1, 0].imshow(scaled_image_bicubic, cmap='gray')
axes[1, 0].set_title('Scaled Image - Bicubic Interpolation')
axes[1, 0].axis('off')

# Відображення масштабованого зображення з ланцюговим згладжуванням
axes[1, 1].imshow(scaled_image_lanczos, cmap='gray')
axes[1, 1].set_title('Scaled Image - Lanczos Interpolation')
axes[1, 1].axis('off')

# Відображення графіків
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Завантаження зображення
image = cv2.imread('res.jpeg', cv2.IMREAD_GRAYSCALE)

# Інвертування зображення
_, inverted_image = cv2.threshold(image, 90, 255, cv2.THRESH_BINARY)

# Налаштування відображення
fig, axes = plt.subplots(1, 2, figsize=(10, 10))

# Відображення оригінального зображення
axes[0].imshow(image, cmap='gray')
axes[0].set_title('Original Image')
axes[0].axis('off')

# Відображення інвертованого зображення
axes[1].imshow(inverted_image, cmap='gray')
axes[1].set_title('thresholded image')
axes[1].axis('off')

# Відображення графіків
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Завантаження зображення
image = cv2.imread('res.jpeg', cv2.IMREAD_GRAYSCALE)

# Інвертування зображення
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (10, 3))
dilated = cv2.dilate(image, kernel, iterations=3)

# Налаштування відображення
fig, axes = plt.subplots(1, 2, figsize=(10, 10))

# Відображення оригінального зображення
axes[0].imshow(image, cmap='gray')
axes[0].set_title('Original Image')
axes[0].axis('off')

# Відображення інвертованого зображення
axes[1].imshow(dilated, cmap='gray')
axes[1].set_title('Inverted Image')
axes[1].axis('off')

# Відображення графіків
plt.show()

# %%
def res_module(input, K_value, stride_val, channel_dim, reduce=False, reg=0.0001, bnEps=2e-5, bnMom=0.9):
    ...

# %%
cv2.IMREAD_REDUCED_COLOR_8

# %%
import cv2

# Читання зображення
img = cv2.imread('res.jpeg')

# Перетворення зображення на відтінки сірого
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Відображення зображення
cv2.imshow('Gray image', gray)

# Очікування на закриття вікна
cv2.waitKey(0)
cv2.destroyAllWindows()
